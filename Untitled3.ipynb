# %% [markdown]
# <a href="https://colab.research.google.com/github/Tru-coder/DemoProject/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Подключение необходимых библиотек

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  Одномерное финитное преобразование Фурье с помощью применения
# алгоритма БПФ.

# %% [markdown]
# Задаём начальные условия

# %%
a1 = -5
a2 = 5

N = 2**10
M = 2**16

b2 = (N * N) / (4 * a2 * M)
b1 = -b2

x = np.linspace(a1, a2, N, endpoint=False)
u = np.linspace(b1, b2, N, endpoint=False)

X, Y = np.meshgrid(x, x)

hx = (a2 - a1) / N

# %% [markdown]
# Реализация БПФ

# %%
def bpf(ff, NN, MM, hx):
  k = (MM - NN) // 2
  F = np.insert(ff, 0, np.zeros(k))
  F = np.append(F, np.zeros(k))

  F = np.fft.fftshift(F)
  F = np.fft.fft(F) * hx
  F = np.fft.fftshift(F)

  F = F[len(F) // 2 - NN // 2: len(F) // 2 + NN // 2]
  return F

# %% [markdown]
# Аналитическое прямое преобразование Фурье

# %%
# integration furie
def chisl(f):
    h_x = 2*a2 / N
    h_u = 2*b2 / N
    F = 0
    arr_F = []
    for i_u in range(N):
        for i_x in range (N):
           F += h_x * (f[i_x]) * np.exp(-2 * np.pi * 1j * x[i_x] * (-b2 + i_u * h_u))
        arr_F.append(F)
        F = 0
    return arr_F

# %% [markdown]
# Задание функций. Гауссов пучок $e^{-x^2}$

# %%
#gauss
gauss = lambda x: np.exp(-x ** 2)

#gauss-original
f_gauss = gauss(x)

#gauss-after-bpf
F_gauss = bpf(f_gauss, N, M, hx)

#gauss-after-integral-method
F_gauss_ch = chisl(f_gauss)

# %% [markdown]
# Функция изображения одномерного графика

# %%
def plot1_1d(ff,xx, strA, strP):
    # График 1
    plt.figure(figsize=(20,10))
    plt.subplot(2, 2, 1)
    plt.plot(xx, np.abs(ff))
    plt.title(strA)
    plt.grid()
    # График 2
    plt.subplot(2, 2, 2)
    plt.plot(xx, np.angle(ff))
    plt.title(strP)
    plt.grid()

# %% [markdown]
# Построить график гауссова пучка $e^{-x^2}$. Графики амплитуды и фазы

# %%
#original gauss
plot1_1d(f_gauss, x,'Амплитуда гауссова пучка','Фаза гауссова пучка')

# %% [markdown]
# Построить график гауссова пучка $e^{-x^2}$. Графики амплитуды и фазы. После БПФ (быстрое преобразование Фурье)

# %%
#gauss after bpf
plot1_1d(F_gauss, u,'Амплитуда гауссова пучка, БПФ','Фаза гауссова пучка, БПФ')

# %% [markdown]
#  Реализовать финитное преобразование Фурье стандартным методом численного
# интегрирования (например, методом прямоугольников).

# %%
#gauss after chisl
plot1_1d(F_gauss_ch, u,'Амплитуда гауссова пучка, численное интегрирование','Фаза гауссова пучка, численное интегрирование')

# %% [markdown]
# Построить результаты двух разных реализаций преобразования на одном
# изображении (одно для амплитуды, одно для фазы) и убедиться, что они совпадают.

# %% [markdown]
# *Изображение двух функций на одной плоскости

# %%
def plot2_1d(ff1, ff2, xx, strA, strP, l1, l2):
    #График 1
    plt.figure(figsize=(20,10))
    plt.subplot(2, 2, 1)
    plt.plot(xx, np.abs(ff1), label = l1, c = 'c', lw = 10)
    plt.plot(xx, np.abs(ff2), label = l2, c = 'k', lw = 3)
    plt.title(strA)
    plt.legend()
    plt.grid()
    # График 2
    plt.subplot(2, 2, 2)
    plt.plot(xx, np.angle(ff1), label = l1, c = 'c', lw = 10)
    plt.plot(xx, np.angle(ff2), label = l2, c = 'k', lw = 3)
    plt.title(strP)
    plt.legend()
    plt.grid()

# %%
plot2_1d(F_gauss, F_gauss_ch, u,'Амплитуда гауссова пучка, БПФ и численное интегрирование','Фаза гауссова пучка, БПФ и численное интегрирование', 'БПФ', 'ЧИ')

# %% [markdown]
# Используя первую реализацию преобразования, подать на вход световое поле,
# отличное от гауссова пучка, в соответствии со своим вариантом (таблица 1).
# Построить графики самого пучка и результата преобразования

# %% [markdown]
# *Прямоугольная функция

# %%
from numpy import linspace, sqrt, sin, exp, convolve, abs, where
...
# Прямоугольная функция
def rect(x):
    return where(abs(x)<=0.5, 1, 0)

# %% [markdown]
# *Задание функции

# %%
#light-original
f = rect(0.5 * x + 1)

#light-after-bpf
F = bpf(f, N, M, hx)

# %% [markdown]
# Графики амплитуды и фазы исходной функции

# %%
#original light
plot1_1d(f, x,'Амплитуда светового поля','Фаза светового поля')

# %% [markdown]
# После БПФ

# %%
#light after bpf
plot1_1d(F, u,'Амплитуда светового поля, БПФ','Фаза светового поля, БПФ')

# %% [markdown]
# Рассчитать аналитически результат преобразования своего варианта поля и
# построить график на одной системе координат с результатом, полученным в
# предыдущем пункте. Аналитический расчёт должен быть помещён в отчёт.
# Прикрепление в отчёт фотографии или скана вывода формулы не является
# допустимым. В некоторых вариантах после преобразования могут появиться особые
# точки. Значения в них нужно вычислять отдельно, в том числе в коде программы

# %% [markdown]
# *Задание функции

# %%
#analitic
def analitic(ksi):
    res=[]
    for i in range(N):
      if (ksi[i] == 0):
        # особая точка
        res.append(2)
      else:
        res.append(np.sin(2*np.pi*ksi[i])/(np.pi*ksi[i]) * np.exp(complex(0, 1)*4*np.pi*ksi[i]))
    return res

# %%
#analitic light
F_an = analitic(u)

# %%
#light analitic + bpf
plot2_1d(F, F_an, u,'Амплитуда гауссова пучка, БПФ и аналитический вариант','Фаза гауссова пучка, БПФ и аналитический вариант', 'БПФ', 'A')
